# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,_=make_blobs(n_samples=1000,centers=5)
print(X.shape)
# Out:
# (1000, 2)

# %%
plt.figure()
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
k=5

colors=['pink','red','green','blue','yellow']

clusters={}

for ix in range(k):
    center=10*(2*np.random.random((X.shape[1],) ) -1)
    
    points=[]
    
    cluster={
        "center":center,
        "points":points,
        "color":colors[ix]
    }
    
    clusters[ix]=cluster
    
print(clusters)
# Out:
# {0: {'center': array([8.05426528, 9.04943525]), 'points': [], 'color': 'pink'}, 1: {'center': array([-2.17397945,  2.84515013]), 'points': [], 'color': 'red'}, 2: {'center': array([-3.01822039, -7.8048338 ]), 'points': [], 'color': 'green'}, 3: {'center': array([-9.26582149,  7.46692031]), 'points': [], 'color': 'blue'}, 4: {'center': array([ 6.96040866, -0.35059362]), 'points': [], 'color': 'yellow'}}

# %%
plt.figure()
plt.scatter(X[:,0],X[:,1])
for ix in range(k):
    plt.scatter(clusters[ix]["center"][0],clusters[ix]["center"][1],color="black",marker="*")
plt.show()

# %%
def distance(x1, y1):
    return np.sqrt(np.sum((x1-x2)**2))

# %%
for ix in range(X.shape[0]):
    dis=[]
    curr_p=X[ix]
    
    for kx in range(k):
        d=distance(curr_p,clusters[kx]["center"])
        dis.append(d)
        
    assigned_cluster=np.argmin(dis)
    
    clusters[assigned_cluster]["points"].append(curr_p)
    
for kx in range(k):
    pnts=np.array(clusters[kx]["points"])
    
    clusters[kx]["coordinates"]=pnts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-af1c5cbf05ef> in <module>
#       4
#       5     for kx in range(k):
# ----> 6         d=distance(curr_p,clusters[kx]["center"])
#       7         dis.append(d)
#       8
#
# <ipython-input-6-9e81b97c9ac2> in distance(x1, y1)
#       1 def distance(x1, y1):
# ----> 2     return np.sqrt(np.sum((x1-x2)**2))
#
# NameError: name 'x2' is not defined
